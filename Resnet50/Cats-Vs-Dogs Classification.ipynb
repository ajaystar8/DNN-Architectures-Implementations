# %%
"""
This is a clone project taken inspiration from Andrew Ng's DeepLearning.AI specialization

The data processing techniques were adopted from FARES ELMENSHAWII's Kaggle Notebook: Cats vs Dogs Classification
"""

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import random
from shutil import copyfile

import tensorflow as tf 
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.initializers import random_uniform, glorot_uniform
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator 

# %matplotlib widget

# %%
def identity_block(X, f, filters, training = True, initializer = random_uniform):
    
    F1, F2, F3 = filters
    X_shortcut = X
    
    X = Conv2D(filters = F1, kernel_size = 1, strides = (1, 1), padding = 'valid', kernel_initializer=initializer(seed = 0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)
    X = Activation("relu")(X)
    
    X = Conv2D(filters = F2, kernel_size = (f,f), strides = (1, 1), padding = 'same', kernel_initializer=initializer(seed = 0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)
    X = Activation("relu")(X)
    
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1, 1), padding = "valid", kernel_initializer = initializer(seed = 0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)
    
    X = Add()([X, X_shortcut])
    X = Activation("relu")(X)
    
    return X

# %%
def convolutional_block(X, f, filters, s = 2, training = True, initializer = glorot_uniform):
    
    F1, F2, F3 = filters
    X_shortcut = X
    
    X = Conv2D(filters = F1, kernel_size = 1, strides = (1, 1), padding = 'valid', kernel_initializer=initializer(seed = 0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)
    X = Activation("relu")(X)
    
    X = Conv2D(filters = F2, kernel_size = (f,f), strides = (1, 1), padding = 'same', kernel_initializer=initializer(seed = 0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)
    X = Activation("relu")(X)
    
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1, 1), padding = "valid", kernel_initializer = initializer(seed = 0))(X)
    X = BatchNormalization(axis = 3)(X, training = training)
    
    X_shortcut = Conv2D(filters = F3, kernel_size = (1, 1), strides = (s,s), padding = "valid", kernel_regularizer = initializer(seed = 0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3)(X, training = training)
    
    X = Add()([X, X_shortcut])
    X = Activation("relu")(X)
    
    return X

# %%
def ResNet50(input_shape = (64, 64, 3), classes = 2):
    
    X_input = Input(input_shape)
    
    X = ZeroPadding2D((3, 3))(X_input)
    
    X = Conv2D(64, (7, 7), strides = (2, 2), kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3)(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)
    
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], s = 1)
    X = identity_block(X, 3, [64, 64, 256])
    X = identity_block(X, 3, [64, 64, 256])

    X = convolutional_block(X, f = 3, filters = [128, 128, 512], s = 2)
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])
    
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], s = 2)
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], s = 2)
    X = identity_block(X, 3, [512, 512, 2048])
    X = identity_block(X, 3, [512, 512, 2048])
    
    X = AveragePooling2D(pool_size = (2,2))(X)
    
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', kernel_initializer = glorot_uniform(seed=0))(X)
    
    model = Model(inputs = X_input, outputs = X)

    return model

# %%
model = ResNet50((64, 64, 3), 2)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  zero_padding2d_3 (ZeroPadding2  (None, 70, 70, 3)   0           ['input_4[0][0]']
#  D)
#
#  conv2d_159 (Conv2D)            (None, 32, 32, 64)   9472        ['zero_padding2d_3[0][0]']
#
#  batch_normalization_159 (Batch  (None, 32, 32, 64)  256         ['conv2d_159[0][0]']
#  Normalization)
#
#  activation_147 (Activation)    (None, 32, 32, 64)   0           ['batch_normalization_159[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 15, 15, 64)  0           ['activation_147[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 15, 15, 64)   4160        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_160 (Batch  (None, 15, 15, 64)  256         ['conv2d_160[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_160[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 15, 15, 64)   36928       ['activation_148[0][0]']
#
#  batch_normalization_161 (Batch  (None, 15, 15, 64)  256         ['conv2d_161[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_161[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 15, 15, 256)  16640       ['activation_149[0][0]']
#
#  batch_normalization_162 (Batch  (None, 15, 15, 256)  1024       ['conv2d_162[0][0]']
#  Normalization)
#
#  batch_normalization_163 (Batch  (None, 15, 15, 256)  1024       ['batch_normalization_162[0][0]']
#  Normalization)
#
#  add_48 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_162[0][0]',
#                                                                   'batch_normalization_163[0][0]']
#
#  activation_150 (Activation)    (None, 15, 15, 256)  0           ['add_48[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 15, 15, 64)   16448       ['activation_150[0][0]']
#
#  batch_normalization_164 (Batch  (None, 15, 15, 64)  256         ['conv2d_164[0][0]']
#  Normalization)
#
#  activation_151 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_164[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 15, 15, 64)   36928       ['activation_151[0][0]']
#
#  batch_normalization_165 (Batch  (None, 15, 15, 64)  256         ['conv2d_165[0][0]']
#  Normalization)
#
#  activation_152 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_165[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 15, 15, 256)  16640       ['activation_152[0][0]']
#
#  batch_normalization_166 (Batch  (None, 15, 15, 256)  1024       ['conv2d_166[0][0]']
#  Normalization)
#
#  add_49 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_166[0][0]',
#                                                                   'activation_150[0][0]']
#
#  activation_153 (Activation)    (None, 15, 15, 256)  0           ['add_49[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 15, 15, 64)   16448       ['activation_153[0][0]']
#
#  batch_normalization_167 (Batch  (None, 15, 15, 64)  256         ['conv2d_167[0][0]']
#  Normalization)
#
#  activation_154 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_167[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 15, 15, 64)   36928       ['activation_154[0][0]']
#
#  batch_normalization_168 (Batch  (None, 15, 15, 64)  256         ['conv2d_168[0][0]']
#  Normalization)
#
#  activation_155 (Activation)    (None, 15, 15, 64)   0           ['batch_normalization_168[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 15, 15, 256)  16640       ['activation_155[0][0]']
#
#  batch_normalization_169 (Batch  (None, 15, 15, 256)  1024       ['conv2d_169[0][0]']
#  Normalization)
#
#  add_50 (Add)                   (None, 15, 15, 256)  0           ['batch_normalization_169[0][0]',
#                                                                   'activation_153[0][0]']
#
#  activation_156 (Activation)    (None, 15, 15, 256)  0           ['add_50[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 15, 15, 128)  32896       ['activation_156[0][0]']
#
#  batch_normalization_170 (Batch  (None, 15, 15, 128)  512        ['conv2d_170[0][0]']
#  Normalization)
#
#  activation_157 (Activation)    (None, 15, 15, 128)  0           ['batch_normalization_170[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 15, 15, 128)  147584      ['activation_157[0][0]']
#
#  batch_normalization_171 (Batch  (None, 15, 15, 128)  512        ['conv2d_171[0][0]']
#  Normalization)
#
#  activation_158 (Activation)    (None, 15, 15, 128)  0           ['batch_normalization_171[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 15, 15, 512)  66048       ['activation_158[0][0]']
#
#  batch_normalization_172 (Batch  (None, 15, 15, 512)  2048       ['conv2d_172[0][0]']
#  Normalization)
#
#  batch_normalization_173 (Batch  (None, 15, 15, 512)  2048       ['batch_normalization_172[0][0]']
#  Normalization)
#
#  add_51 (Add)                   (None, 15, 15, 512)  0           ['batch_normalization_172[0][0]',
#                                                                   'batch_normalization_173[0][0]']
#
#  activation_159 (Activation)    (None, 15, 15, 512)  0           ['add_51[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 15, 15, 128)  65664       ['activation_159[0][0]']
#
#  batch_normalization_174 (Batch  (None, 15, 15, 128)  512        ['conv2d_174[0][0]']
#  Normalization)
#
#  activation_160 (Activation)    (None, 15, 15, 128)  0           ['batch_normalization_174[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 15, 15, 128)  147584      ['activation_160[0][0]']
#
#  batch_normalization_175 (Batch  (None, 15, 15, 128)  512        ['conv2d_175[0][0]']
#  Normalization)
#
#  activation_161 (Activation)    (None, 15, 15, 128)  0           ['batch_normalization_175[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 15, 15, 512)  66048       ['activation_161[0][0]']
#
#  batch_normalization_176 (Batch  (None, 15, 15, 512)  2048       ['conv2d_176[0][0]']
#  Normalization)
#
#  add_52 (Add)                   (None, 15, 15, 512)  0           ['batch_normalization_176[0][0]',
#                                                                   'activation_159[0][0]']
#
#  activation_162 (Activation)    (None, 15, 15, 512)  0           ['add_52[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 15, 15, 128)  65664       ['activation_162[0][0]']
#
#  batch_normalization_177 (Batch  (None, 15, 15, 128)  512        ['conv2d_177[0][0]']
#  Normalization)
#
#  activation_163 (Activation)    (None, 15, 15, 128)  0           ['batch_normalization_177[0][0]']
#
#  conv2d_178 (Conv2D)            (None, 15, 15, 128)  147584      ['activation_163[0][0]']
#
#  batch_normalization_178 (Batch  (None, 15, 15, 128)  512        ['conv2d_178[0][0]']
#  Normalization)
#
#  activation_164 (Activation)    (None, 15, 15, 128)  0           ['batch_normalization_178[0][0]']
#
#  conv2d_179 (Conv2D)            (None, 15, 15, 512)  66048       ['activation_164[0][0]']
#
#  batch_normalization_179 (Batch  (None, 15, 15, 512)  2048       ['conv2d_179[0][0]']
#  Normalization)
#
#  add_53 (Add)                   (None, 15, 15, 512)  0           ['batch_normalization_179[0][0]',
#                                                                   'activation_162[0][0]']
#
#  activation_165 (Activation)    (None, 15, 15, 512)  0           ['add_53[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 15, 15, 128)  65664       ['activation_165[0][0]']
#
#  batch_normalization_180 (Batch  (None, 15, 15, 128)  512        ['conv2d_180[0][0]']
#  Normalization)
#
#  activation_166 (Activation)    (None, 15, 15, 128)  0           ['batch_normalization_180[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 15, 15, 128)  147584      ['activation_166[0][0]']
#
#  batch_normalization_181 (Batch  (None, 15, 15, 128)  512        ['conv2d_181[0][0]']
#  Normalization)
#
#  activation_167 (Activation)    (None, 15, 15, 128)  0           ['batch_normalization_181[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 15, 15, 512)  66048       ['activation_167[0][0]']
#
#  batch_normalization_182 (Batch  (None, 15, 15, 512)  2048       ['conv2d_182[0][0]']
#  Normalization)
#
#  add_54 (Add)                   (None, 15, 15, 512)  0           ['batch_normalization_182[0][0]',
#                                                                   'activation_165[0][0]']
#
#  activation_168 (Activation)    (None, 15, 15, 512)  0           ['add_54[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 15, 15, 256)  131328      ['activation_168[0][0]']
#
#  batch_normalization_183 (Batch  (None, 15, 15, 256)  1024       ['conv2d_183[0][0]']
#  Normalization)
#
#  activation_169 (Activation)    (None, 15, 15, 256)  0           ['batch_normalization_183[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 15, 15, 256)  590080      ['activation_169[0][0]']
#
#  batch_normalization_184 (Batch  (None, 15, 15, 256)  1024       ['conv2d_184[0][0]']
#  Normalization)
#
#  activation_170 (Activation)    (None, 15, 15, 256)  0           ['batch_normalization_184[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 15, 15, 1024  263168      ['activation_170[0][0]']
#                                 )
#
#  batch_normalization_185 (Batch  (None, 15, 15, 1024  4096       ['conv2d_185[0][0]']
#  Normalization)                 )
#
#  batch_normalization_186 (Batch  (None, 15, 15, 1024  4096       ['batch_normalization_185[0][0]']
#  Normalization)                 )
#
#  add_55 (Add)                   (None, 15, 15, 1024  0           ['batch_normalization_185[0][0]',
#                                 )                                 'batch_normalization_186[0][0]']
#
#  activation_171 (Activation)    (None, 15, 15, 1024  0           ['add_55[0][0]']
#                                 )
#
#  conv2d_187 (Conv2D)            (None, 15, 15, 256)  262400      ['activation_171[0][0]']
#
#  batch_normalization_187 (Batch  (None, 15, 15, 256)  1024       ['conv2d_187[0][0]']
#  Normalization)
#
#  activation_172 (Activation)    (None, 15, 15, 256)  0           ['batch_normalization_187[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 15, 15, 256)  590080      ['activation_172[0][0]']
#
#  batch_normalization_188 (Batch  (None, 15, 15, 256)  1024       ['conv2d_188[0][0]']
#  Normalization)
#
#  activation_173 (Activation)    (None, 15, 15, 256)  0           ['batch_normalization_188[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 15, 15, 1024  263168      ['activation_173[0][0]']
#                                 )
#
#  batch_normalization_189 (Batch  (None, 15, 15, 1024  4096       ['conv2d_189[0][0]']
#  Normalization)                 )
#
#  add_56 (Add)                   (None, 15, 15, 1024  0           ['batch_normalization_189[0][0]',
#                                 )                                 'activation_171[0][0]']
#
#  activation_174 (Activation)    (None, 15, 15, 1024  0           ['add_56[0][0]']
#                                 )
#
#  conv2d_190 (Conv2D)            (None, 15, 15, 256)  262400      ['activation_174[0][0]']
#
#  batch_normalization_190 (Batch  (None, 15, 15, 256)  1024       ['conv2d_190[0][0]']
#  Normalization)
#
#  activation_175 (Activation)    (None, 15, 15, 256)  0           ['batch_normalization_190[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 15, 15, 256)  590080      ['activation_175[0][0]']
#
#  batch_normalization_191 (Batch  (None, 15, 15, 256)  1024       ['conv2d_191[0][0]']
#  Normalization)
#
#  activation_176 (Activation)    (None, 15, 15, 256)  0           ['batch_normalization_191[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 15, 15, 1024  263168      ['activation_176[0][0]']
#                                 )
#
#  batch_normalization_192 (Batch  (None, 15, 15, 1024  4096       ['conv2d_192[0][0]']
#  Normalization)                 )
#
#  add_57 (Add)                   (None, 15, 15, 1024  0           ['batch_normalization_192[0][0]',
#                                 )                                 'activation_174[0][0]']
#
#  activation_177 (Activation)    (None, 15, 15, 1024  0           ['add_57[0][0]']
#                                 )
#
#  conv2d_193 (Conv2D)            (None, 15, 15, 256)  262400      ['activation_177[0][0]']
#
#  batch_normalization_193 (Batch  (None, 15, 15, 256)  1024       ['conv2d_193[0][0]']
#  Normalization)
#
#  activation_178 (Activation)    (None, 15, 15, 256)  0           ['batch_normalization_193[0][0]']
#
#  conv2d_194 (Conv2D)            (None, 15, 15, 256)  590080      ['activation_178[0][0]']
#
#  batch_normalization_194 (Batch  (None, 15, 15, 256)  1024       ['conv2d_194[0][0]']
#  Normalization)
#
#  activation_179 (Activation)    (None, 15, 15, 256)  0           ['batch_normalization_194[0][0]']
#
#  conv2d_195 (Conv2D)            (None, 15, 15, 1024  263168      ['activation_179[0][0]']
#                                 )
#
#  batch_normalization_195 (Batch  (None, 15, 15, 1024  4096       ['conv2d_195[0][0]']
#  Normalization)                 )
#
#  add_58 (Add)                   (None, 15, 15, 1024  0           ['batch_normalization_195[0][0]',
#                                 )                                 'activation_177[0][0]']
#
#  activation_180 (Activation)    (None, 15, 15, 1024  0           ['add_58[0][0]']
#                                 )
#
#  conv2d_196 (Conv2D)            (None, 15, 15, 256)  262400      ['activation_180[0][0]']
#
#  batch_normalization_196 (Batch  (None, 15, 15, 256)  1024       ['conv2d_196[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 15, 15, 256)  0           ['batch_normalization_196[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 15, 15, 256)  590080      ['activation_181[0][0]']
#
#  batch_normalization_197 (Batch  (None, 15, 15, 256)  1024       ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_182 (Activation)    (None, 15, 15, 256)  0           ['batch_normalization_197[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 15, 15, 1024  263168      ['activation_182[0][0]']
#                                 )
#
#  batch_normalization_198 (Batch  (None, 15, 15, 1024  4096       ['conv2d_198[0][0]']
#  Normalization)                 )
#
#  add_59 (Add)                   (None, 15, 15, 1024  0           ['batch_normalization_198[0][0]',
#                                 )                                 'activation_180[0][0]']
#
#  activation_183 (Activation)    (None, 15, 15, 1024  0           ['add_59[0][0]']
#                                 )
#
#  conv2d_199 (Conv2D)            (None, 15, 15, 256)  262400      ['activation_183[0][0]']
#
#  batch_normalization_199 (Batch  (None, 15, 15, 256)  1024       ['conv2d_199[0][0]']
#  Normalization)
#
#  activation_184 (Activation)    (None, 15, 15, 256)  0           ['batch_normalization_199[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 15, 15, 256)  590080      ['activation_184[0][0]']
#
#  batch_normalization_200 (Batch  (None, 15, 15, 256)  1024       ['conv2d_200[0][0]']
#  Normalization)
#
#  activation_185 (Activation)    (None, 15, 15, 256)  0           ['batch_normalization_200[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 15, 15, 1024  263168      ['activation_185[0][0]']
#                                 )
#
#  batch_normalization_201 (Batch  (None, 15, 15, 1024  4096       ['conv2d_201[0][0]']
#  Normalization)                 )
#
#  add_60 (Add)                   (None, 15, 15, 1024  0           ['batch_normalization_201[0][0]',
#                                 )                                 'activation_183[0][0]']
#
#  activation_186 (Activation)    (None, 15, 15, 1024  0           ['add_60[0][0]']
#                                 )
#
#  conv2d_202 (Conv2D)            (None, 15, 15, 512)  524800      ['activation_186[0][0]']
#
#  batch_normalization_202 (Batch  (None, 15, 15, 512)  2048       ['conv2d_202[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 15, 15, 512)  0           ['batch_normalization_202[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 15, 15, 512)  2359808     ['activation_187[0][0]']
#
#  batch_normalization_203 (Batch  (None, 15, 15, 512)  2048       ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_188 (Activation)    (None, 15, 15, 512)  0           ['batch_normalization_203[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 15, 15, 2048  1050624     ['activation_188[0][0]']
#                                 )
#
#  batch_normalization_204 (Batch  (None, 15, 15, 2048  8192       ['conv2d_204[0][0]']
#  Normalization)                 )
#
#  batch_normalization_205 (Batch  (None, 15, 15, 2048  8192       ['batch_normalization_204[0][0]']
#  Normalization)                 )
#
#  add_61 (Add)                   (None, 15, 15, 2048  0           ['batch_normalization_204[0][0]',
#                                 )                                 'batch_normalization_205[0][0]']
#
#  activation_189 (Activation)    (None, 15, 15, 2048  0           ['add_61[0][0]']
#                                 )
#
#  conv2d_206 (Conv2D)            (None, 15, 15, 512)  1049088     ['activation_189[0][0]']
#
#  batch_normalization_206 (Batch  (None, 15, 15, 512)  2048       ['conv2d_206[0][0]']
#  Normalization)
#
#  activation_190 (Activation)    (None, 15, 15, 512)  0           ['batch_normalization_206[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 15, 15, 512)  2359808     ['activation_190[0][0]']
#
#  batch_normalization_207 (Batch  (None, 15, 15, 512)  2048       ['conv2d_207[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 15, 15, 512)  0           ['batch_normalization_207[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 15, 15, 2048  1050624     ['activation_191[0][0]']
#                                 )
#
#  batch_normalization_208 (Batch  (None, 15, 15, 2048  8192       ['conv2d_208[0][0]']
#  Normalization)                 )
#
#  add_62 (Add)                   (None, 15, 15, 2048  0           ['batch_normalization_208[0][0]',
#                                 )                                 'activation_189[0][0]']
#
#  activation_192 (Activation)    (None, 15, 15, 2048  0           ['add_62[0][0]']
#                                 )
#
#  conv2d_209 (Conv2D)            (None, 15, 15, 512)  1049088     ['activation_192[0][0]']
#
#  batch_normalization_209 (Batch  (None, 15, 15, 512)  2048       ['conv2d_209[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 15, 15, 512)  0           ['batch_normalization_209[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 15, 15, 512)  2359808     ['activation_193[0][0]']
#
#  batch_normalization_210 (Batch  (None, 15, 15, 512)  2048       ['conv2d_210[0][0]']
#  Normalization)
#
#  activation_194 (Activation)    (None, 15, 15, 512)  0           ['batch_normalization_210[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 15, 15, 2048  1050624     ['activation_194[0][0]']
#                                 )
#
#  batch_normalization_211 (Batch  (None, 15, 15, 2048  8192       ['conv2d_211[0][0]']
#  Normalization)                 )
#
#  add_63 (Add)                   (None, 15, 15, 2048  0           ['batch_normalization_211[0][0]',
#                                 )                                 'activation_192[0][0]']
#
#  activation_195 (Activation)    (None, 15, 15, 2048  0           ['add_63[0][0]']
#                                 )
#
#  average_pooling2d_2 (AveragePo  (None, 7, 7, 2048)  0           ['activation_195[0][0]']
#  oling2D)
#
#  flatten_2 (Flatten)            (None, 100352)       0           ['average_pooling2d_2[0][0]']
#
#  dense_2 (Dense)                (None, 2)            200706      ['flatten_2[0][0]']
#
# ==================================================================================================
# Total params: 21,015,682
# Trainable params: 20,962,562
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Cat vs Dog Classification

# %%
# Getting to know the dataset

class_names = ["Cat", "Dog"]

n_dogs = len(os.listdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/PetImages/Dog'))
n_cats = len(os.listdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/PetImages/Cat'))

n_images = [n_cats, n_dogs]
print(n_images)
# Out:
# [12501, 12501]

# %%
# Creation of new empty directories for re-arranging the dataset
try:
    os.mkdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs')
    
    os.mkdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/training')
    os.mkdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/validation')
    os.mkdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/test')
    
    os.mkdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/training/cats')
    os.mkdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/training/dogs')
    
    os.mkdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/validation/cats')
    os.mkdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/validation/dogs')
    
    os.mkdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/test/cats')
    os.mkdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/test/dogs')
except OSError:
    print('Error failed to make directory')

# %% [markdown]
# ### Creation of path variables

# %%
CAT_DIR = '/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/PetImages/Cat'
DOG_DIR = '/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/PetImages/Dog'

TRAINING_DIR = '/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/training'
VALIDATION_DIR = '/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/validation'

TRAINING_CATS = os.path.join(TRAINING_DIR, "cats/")
VALIDATION_CATS = os.path.join(VALIDATION_DIR, "cats/")

TRAINING_DOGS = os.path.join(TRAINING_DIR, "dogs/")
VALIDATION_DOGS = os.path.join(VALIDATION_DIR, "dogs/")

INCLUDE_TEST = True

# %% [markdown]
# ### Filling up the train, validation an test folders with data

# %%
def split_data(main_dir, training_dir, validation_dir, test_dir=None, include_test_split = True,  split_size=0.9):
    """
    Splits the data into train, validation and test sets (optional)

    Arguements:
    main_dir (string):  path containing the images
    training_dir (string):  path to data to be used for training
    validation_dir (string):  path to data to be used for validation
    test_dir (string):  path to data to be used for test
    include_test_split (boolean):  whether to include a test set or not
    split_size (float): size of the dataset to be used for training
    """
    
    # this list contains all the images we have
    files = []
    for file in os.listdir(main_dir):
        if  os.path.getsize(os.path.join(main_dir, file)): # check if the file's size isn't 0
            files.append(file) # appends file name to the list

    shuffled_files = random.sample(files,  len(files)) # shuffles the data
    split = int(0.9 * len(shuffled_files)) #the training split casted into int for numeric rounding
    train = shuffled_files[:split] #training split
    
    # ==========(train)|==(rem data for test and validation)
    # remaining data is split equally between validation and test sets
    split_valid_test = int(split + (len(shuffled_files)-split)/2)
   
    if include_test_split:
        validation = shuffled_files[split:split_valid_test] # validation split
        test = shuffled_files[split_valid_test:] # test split 
    else:
        validation = shuffled_files[split:] # remaining data entirely goes to validation split

    for element in train:
        copyfile(os.path.join(main_dir,  element), os.path.join(training_dir, element)) # copy files into training directory

    for element in validation:
        copyfile(os.path.join(main_dir,  element), os.path.join(validation_dir, element))# copy files into validation directory
        
    if include_test_split:
        for element in test:
            copyfile(os.path.join(main_dir,  element), os.path.join(test_dir, element)) # copy files into test directory
    print("Split sucessful!")

# %%
split_data(CAT_DIR, '/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/training/cats', '/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/validation/cats', '/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/test/cats',INCLUDE_TEST, 0.9)
split_data(DOG_DIR, '/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/training/dogs', '/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/validation/dogs', '/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/test/dogs', INCLUDE_TEST, 0.9)

# %% [markdown]
# ### Sanity Checking

# %%
print(len(os.listdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/training/cats')))
print(len(os.listdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/training/dogs')))

print(len(os.listdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/validation/cats')))
print(len(os.listdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/validation/dogs')))


print(len(os.listdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/test/cats')))
print(len(os.listdir('/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/test/dogs')))
# Out:
# 11250
# 11250
# 625
# 625
# 625
# 625

# %%
train_gen = ImageDataGenerator(
        rescale=1./255)


validation_gen =  ImageDataGenerator(
        rescale=1./255.)

if INCLUDE_TEST:
    test_gen =  ImageDataGenerator(
            rescale=1./255.)

# %%
train_generator = train_gen.flow_from_directory(
        '/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/training',
        target_size=(64, 64),
        batch_size=64,
        class_mode='binary')

validation_generator = validation_gen.flow_from_directory(
        '/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/validation',
        target_size=(64, 64),
        batch_size=64,
        class_mode='binary')

if INCLUDE_TEST:
    test_generator = test_gen.flow_from_directory(
        '/Volumes/Samsung_T5/ML_Prac/DNN_Architectures/Resnet50/tmp/cats-v-dogs/test',
        target_size=(64, 64),
        batch_size=64,
        class_mode='binary')
# Out:
# Found 22498 images belonging to 2 classes.
# Found 1250 images belonging to 2 classes.
# Found 1250 images belonging to 2 classes.

# %%
class_names = ['Cat', 'Dog']
def plot_data(generator, n_images):
    """
    Plots random data from dataset
    Args:
    generator: a generator instance
    n_images : number of images to plot
    """
    i = 1
    images, labels = generator.next()
    labels = labels.astype('int32')
    
    for image, label in zip(images, labels):
        plt.figure()
        plt.imshow(image)
        plt.title(class_names[label])
        plt.axis('off')
        i += 1
        if i == n_images:
            break
    
    plt.show()

# %%
plot_data(validation_generator,2)

# %%
model.fit(train_generator, epochs = 10, validation_data=validation_generator)
